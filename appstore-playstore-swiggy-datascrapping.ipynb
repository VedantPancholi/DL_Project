# %%
# !pip install google-play-scraper app_store_scraper pandas
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Collecting app_store_scraper
#   Downloading app_store_scraper-0.3.5-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.3)
# Collecting requests==2.23.0 (from app_store_scraper)
#   Downloading requests-2.23.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting chardet<4,>=3.0.2 (from requests==2.23.0->app_store_scraper)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna<3,>=2.5 (from requests==2.23.0->app_store_scraper)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests==2.23.0->app_store_scraper)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2025.1.31)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pandas) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.22.4->pandas) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.22.4->pandas) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pandas) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.22.4->pandas) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.22.4->pandas) (2024.2.0)
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Downloading app_store_scraper-0.3.5-py3-none-any.whl (8.3 kB)
# Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.4 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.6 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.3 MB/s eta 0:00:00
# Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: chardet, urllib3, idna, google-play-scraper, requests, app_store_scraper
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.29.0 requires requests>=2.27.1, but you have requests 2.23.0 which is incompatible.
# datasets 3.2.0 requires requests>=2.32.2, but you have requests 2.23.0 which is incompatible.
# distributed 2024.11.2 requires urllib3>=1.26.5, but you have urllib3 1.25.11 which is incompatible.
# docker 7.1.0 requires requests>=2.26.0, but you have requests 2.23.0 which is incompatible.
# docker 7.1.0 requires urllib3>=1.26.0, but you have urllib3 1.25.11 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.23.0 which is incompatible.
# google-genai 0.2.2 requires requests<3.0.0dev,>=2.28.1, but you have requests 2.23.0 which is incompatible.
# jupyterlab-server 2.27.3 requires requests>=2.31, but you have requests 2.23.0 which is incompatible.
# kaggle-environments 1.16.11 requires requests>=2.25.1, but you have requests 2.23.0 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# libpysal 4.9.2 requires requests>=2.27, but you have requests 2.23.0 which is incompatible.
# nilearn 0.10.4 requires requests>=2.25.0, but you have requests 2.23.0 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# sentry-sdk 2.19.2 requires urllib3>=1.26.11, but you have urllib3 1.25.11 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.23.0 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# tiktoken 0.8.0 requires requests>=2.26.0, but you have requests 2.23.0 which is incompatible.
# tweepy 4.14.0 requires requests<3,>=2.27.0, but you have requests 2.23.0 which is incompatible.
# ydata-profiling 4.12.2 requires requests<3,>=2.24.0, but you have requests 2.23.0 which is incompatible.
# yfinance 0.2.50 requires requests>=2.31, but you have requests 2.23.0 which is incompatible.
# Successfully installed app_store_scraper-0.3.5 chardet-3.0.4 google-play-scraper-1.2.7 idna-2.10 requests-2.23.0 urllib3-1.25.11

# %%
from google_play_scraper import reviews_all, Sort
from app_store_scraper import AppStore
import pandas as pd

# 🎯 Google Play Store Scraper
app_package = "in.swiggy.android"  # Google Play package name

g_reviews = reviews_all(
    app_package,
    sleep_milliseconds=0,  
    lang="en",             
    country="in",          
    sort=Sort.NEWEST       
)

# Convert to DataFrame
df_google = pd.DataFrame(g_reviews)

# ✅ Add Extra Columns
df_google["Company"] = "Swiggy"
df_google["Platform"] = "Google Play Store"

# %%
# 🎯 Apple App Store Scraper (Corrected ID)
app_store_id = "989540920"  # Corrected Apple App Store ID

a_reviews = AppStore(country="in", app_name="swiggy-food-instamart-dineout", app_id=app_store_id)
a_reviews.review()  

# Convert to DataFrame
df_apple = pd.DataFrame(a_reviews.reviews)

# ✅ Add Extra Columns
df_apple["Company"] = "Swiggy"
df_apple["Platform"] = "App Store"

# 🎯 Combine Both DataFrames
df_combined = pd.concat([df_google, df_apple], ignore_index=True)

# Print the combined DataFrame
print("✅ Combined Reviews:\n", df_combined.head())

# ✅ Display Shape of Data
print(f"\nTotal Reviews Combined: {df_combined.shape[0]}")
# Out:
# ✅ Combined Reviews:
#                                 reviewId       userName  \
# 0  e8af1c09-470e-465b-8ddc-3f945cabace6  A Google user
# 1  edab8780-bff4-4c56-bf0b-05ea41194974  A Google user
# 2  17d2332c-cfcf-4c4f-a0f4-a014f702834c  A Google user
# 3  47fd0596-0c0a-4fdf-87e9-8e8dfe1355bc  A Google user
# 4  5e95bd61-4b53-4e70-8f95-89d72470d34d  A Google user
#
#                                            userImage                 content  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...                    good
# 1  https://play-lh.googleusercontent.com/EGemoI2N...                    good
# 2  https://play-lh.googleusercontent.com/EGemoI2N...       excellent service
# 3  https://play-lh.googleusercontent.com/EGemoI2N...  food is very worstfood
# 4  https://play-lh.googleusercontent.com/EGemoI2N...          warest service
#
#    score  thumbsUpCount reviewCreatedVersion                  at  \
# 0    5.0            0.0               4.73.2 2025-02-10 18:32:49
# 1    5.0            0.0               4.73.1 2025-02-10 18:31:39
# 2    5.0            0.0               4.73.2 2025-02-10 18:31:12
# 3    1.0            0.0               4.73.2 2025-02-10 18:29:23
# 4    1.0            0.0               4.71.1 2025-02-10 18:24:05
#
#                                         replyContent           repliedAt  \
# 0  Hi there, thank you for your patronage and the... 2025-02-10 18:42:33
# 1  Hey, thanks for the rating! This motivates us ... 2025-02-10 18:32:26
# 2  Hey there, we're pleased that you enjoyed your... 2025-02-10 18:32:27
# 3  Hi there, we are sorry for any hassle you have... 2025-02-10 18:32:26
# 4  Hello, we would like to know more about it. Pl... 2025-02-10 18:32:26
#
#   appVersion Company           Platform date review  rating isEdited title  \
# 0     4.73.2  Swiggy  Google Play Store  NaT    NaN     NaN      NaN   NaN
# 1     4.73.1  Swiggy  Google Play Store  NaT    NaN     NaN      NaN   NaN
# 2     4.73.2  Swiggy  Google Play Store  NaT    NaN     NaN      NaN   NaN
# 3     4.73.2  Swiggy  Google Play Store  NaT    NaN     NaN      NaN   NaN
# 4     4.71.1  Swiggy  Google Play Store  NaT    NaN     NaN      NaN   NaN
#
#   developerResponse
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# Total Reviews Combined: 1361958
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()

# %%
df_combined.shape[0]
# Out:
# 1361958

# %%
df_combined.isnull().sum()
# Out:
# reviewId                   3240
# userName                      0
# userImage                  3240
# content                    3246
# score                      3240
# thumbsUpCount              3240
# reviewCreatedVersion     228828
# at                         3240
# replyContent              21947
# repliedAt                 21947
# appVersion               228828
# Company                       0
# Platform                      0
# date                    1358718
# review                  1358718
# rating                  1358718
# isEdited                1358718
# title                   1358718
# developerResponse       1359351
# dtype: int64

# %%
df_combined.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion', 'Company', 'Platform', 'date', 'review',
#        'rating', 'isEdited', 'title', 'developerResponse'],
#       dtype='object')

# %%
df_new = df_combined.drop(columns = ['reviewId', 'userName', 'userImage', 'reviewCreatedVersion', 'appVersion', 'date', 'review',
       'rating', 'isEdited', 'title', 'developerResponse'])
df_new.columns
# Out:
# Index(['content', 'score', 'thumbsUpCount', 'at', 'replyContent', 'repliedAt',
#        'Company', 'Platform'],
#       dtype='object')

# %%
df_new
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                         content  score  thumbsUpCount                  at  \
# 0                          good    5.0            0.0 2025-02-10 18:32:49
# 1                          good    5.0            0.0 2025-02-10 18:31:39
# 2             excellent service    5.0            0.0 2025-02-10 18:31:12
# 3        food is very worstfood    1.0            0.0 2025-02-10 18:29:23
# 4                warest service    1.0            0.0 2025-02-10 18:24:05
# ...                         ...    ...            ...                 ...
# 1361953                     NaN    NaN            NaN                 NaT
# 1361954                     NaN    NaN            NaN                 NaT
# 1361955                     NaN    NaN            NaN                 NaT
# 1361956                     NaN    NaN            NaN                 NaT
# 1361957                     NaN    NaN            NaN                 NaT
#
#                                               replyContent  \
# 0        Hi there, thank you for your patronage and the...
# 1        Hey, thanks for the rating! This motivates us ...
# 2        Hey there, we're pleased that you enjoyed your...
# 3        Hi there, we are sorry for any hassle you have...
# 4        Hello, we would like to know more about it. Pl...
# ...                                                    ...
# 1361953                                                NaN
# 1361954                                                NaN
# 1361955                                                NaN
# 1361956                                                NaN
# 1361957                                                NaN
#
#                   repliedAt Company           Platform
# 0       2025-02-10 18:42:33  Swiggy  Google Play Store
# 1       2025-02-10 18:32:26  Swiggy  Google Play Store
# 2       2025-02-10 18:32:27  Swiggy  Google Play Store
# 3       2025-02-10 18:32:26  Swiggy  Google Play Store
# 4       2025-02-10 18:32:26  Swiggy  Google Play Store
# ...                     ...     ...                ...
# 1361953                 NaT  Swiggy          App Store
# 1361954                 NaT  Swiggy          App Store
# 1361955                 NaT  Swiggy          App Store
# 1361956                 NaT  Swiggy          App Store
# 1361957                 NaT  Swiggy          App Store
#
# [1361958 rows x 8 columns]

# %%
df_new.isnull().sum()
# Out:
# content           3246
# score             3240
# thumbsUpCount     3240
# at                3240
# replyContent     21947
# repliedAt        21947
# Company              0
# Platform             0
# dtype: int64

# %%
df2_new = df_new.dropna()
df2_new
# Out:
#                                                    content  score  \
# 0                                                     good    5.0
# 1                                                     good    5.0
# 2                                        excellent service    5.0
# 3                                   food is very worstfood    1.0
# 4                                           warest service    1.0
# ...                                                    ...    ...
# 1358713  This is great! It was a little tough to keep p...    5.0
# 1358714                               They are super speed    5.0
# 1358715  Great app. Quick and  reliable services a clic...    5.0
# 1358716  Not able to register on app and order... Recei...    1.0
# 1358717  I ordered at 8PM. I had to get in touch with a...    1.0
#
#          thumbsUpCount                  at  \
# 0                  0.0 2025-02-10 18:32:49
# 1                  0.0 2025-02-10 18:31:39
# 2                  0.0 2025-02-10 18:31:12
# 3                  0.0 2025-02-10 18:29:23
# 4                  0.0 2025-02-10 18:24:05
# ...                ...                 ...
# 1358713            1.0 2015-03-28 10:48:45
# 1358714            1.0 2015-03-28 10:25:23
# 1358715            2.0 2015-03-27 15:48:37
# 1358716            2.0 2015-03-25 16:11:36
# 1358717            4.0 2015-03-22 16:39:36
#
#                                               replyContent  \
# 0        Hi there, thank you for your patronage and the...
# 1        Hey, thanks for the rating! This motivates us ...
# 2        Hey there, we're pleased that you enjoyed your...
# 3        Hi there, we are sorry for any hassle you have...
# 4        Hello, we would like to know more about it. Pl...
# ...                                                    ...
# 1358713  Dear Sania,\n\nWe got glued on your feedback.W...
# 1358714  Dear Durga,\n\nYour incessant delight is our r...
# 1358715  Dear Abishek,\n\nWe are always excited about o...
# 1358716  Kartik,\nExtremely sorry about the experience ...
# 1358717  Mayur,\nWe are very sorry for the experience y...
#
#                   repliedAt Company           Platform
# 0       2025-02-10 18:42:33  Swiggy  Google Play Store
# 1       2025-02-10 18:32:26  Swiggy  Google Play Store
# 2       2025-02-10 18:32:27  Swiggy  Google Play Store
# 3       2025-02-10 18:32:26  Swiggy  Google Play Store
# 4       2025-02-10 18:32:26  Swiggy  Google Play Store
# ...                     ...     ...                ...
# 1358713 2015-03-28 13:06:02  Swiggy  Google Play Store
# 1358714 2015-03-28 10:36:11  Swiggy  Google Play Store
# 1358715 2015-03-27 17:25:20  Swiggy  Google Play Store
# 1358716 2015-03-26 15:17:10  Swiggy  Google Play Store
# 1358717 2015-03-24 10:09:05  Swiggy  Google Play Store
#
# [1340005 rows x 8 columns]

# %%
df2_new['Platform'].unique()
# Out:
# array(['Google Play Store'], dtype=object)

# %%
df_apple
# Out:
#                     date                                             review  \
# 0    2023-09-01 17:42:17  Almost it has been 3 weeks since I have been t...
# 1    2024-11-10 14:42:27  I have had multiple instances now of poor cust...
# 2    2024-11-10 20:06:17  I have placed the order in Swiggy with Box8 re...
# 3    2022-11-26 17:26:05  Long time user here from the early days and Sw...
# 4    2024-11-23 08:56:00  I have faced this issue multiple times but nev...
# ...                  ...                                                ...
# 3235 2024-10-08 02:09:50  Love the UX of the app. Of all the apps I have...
# 3236 2024-11-21 15:16:15  When I placed order, it showed 25 minutes to b...
# 3237 2024-11-11 06:00:59  I am a student, and Swiggy has fraud me, witho...
# 3238 2024-10-30 09:51:23  I have paid for food which included tip of x a...
# 3239 2024-10-01 07:48:44  worst customer service ever seen. \ni have ord...
#
#       rating  isEdited           userName  \
# 0          5     False              rajkn
# 1          1     False   Akshta Choudhary
# 2          1     False       Sujan Reaper
# 3          1     False            sweptby
# 4          1     False        Joooyyyy123
# ...      ...       ...                ...
# 3235       5     False           Rhythorn
# 3236       1     False           Mr kosgi
# 3237       1     False  zxdsqwerfasxcfdwx
# 3238       1     False           S@chin03
# 3239       1     False          Sidd@1704
#
#                                                   title  \
# 0                         Unempathatic Customer Support
# 1     Jaipur instamart - Pathetic customer support, ...
# 2     Worst customer support and false delivery comm...
# 3          Service pathetic these days avoid Swiggy one
# 4                                        Worst food app
# ...                                                 ...
# 3235                      Great UI, Great functionality
# 3236                                        No Response
# 3237                   Complain of customer care itself
# 3238                                 Refund without tip
# 3239                customer service & delivery person.
#
#                                       developerResponse Company   Platform
# 0                                                   NaN  Swiggy  App Store
# 1     {'id': 48140594, 'body': 'We're disappointed t...  Swiggy  App Store
# 2     {'id': 48140595, 'body': 'Hello, we would like...  Swiggy  App Store
# 3                                                   NaN  Swiggy  App Store
# 4     {'id': 48452648, 'body': 'Hey there, that shou...  Swiggy  App Store
# ...                                                 ...     ...        ...
# 3235  {'id': 47321562, 'body': 'Hey there, we are th...  Swiggy  App Store
# 3236  {'id': 48430133, 'body': 'Hey there, that shou...  Swiggy  App Store
# 3237  {'id': 48166923, 'body': 'That doesn't seem ri...  Swiggy  App Store
# 3238  {'id': 47867386, 'body': 'Hi, we are sorry abo...  Swiggy  App Store
# 3239  {'id': 47166813, 'body': 'Hey there, that shou...  Swiggy  App Store
#
# [3240 rows x 9 columns]

# %%
df3_playstore = df2_new.drop(columns = ['thumbsUpCount', 'Company'])
df3_playstore
# Out:
#                                                    content  score  \
# 0                                                     good    5.0
# 1                                                     good    5.0
# 2                                        excellent service    5.0
# 3                                   food is very worstfood    1.0
# 4                                           warest service    1.0
# ...                                                    ...    ...
# 1358713  This is great! It was a little tough to keep p...    5.0
# 1358714                               They are super speed    5.0
# 1358715  Great app. Quick and  reliable services a clic...    5.0
# 1358716  Not able to register on app and order... Recei...    1.0
# 1358717  I ordered at 8PM. I had to get in touch with a...    1.0
#
#                          at  \
# 0       2025-02-10 18:32:49
# 1       2025-02-10 18:31:39
# 2       2025-02-10 18:31:12
# 3       2025-02-10 18:29:23
# 4       2025-02-10 18:24:05
# ...                     ...
# 1358713 2015-03-28 10:48:45
# 1358714 2015-03-28 10:25:23
# 1358715 2015-03-27 15:48:37
# 1358716 2015-03-25 16:11:36
# 1358717 2015-03-22 16:39:36
#
#                                               replyContent  \
# 0        Hi there, thank you for your patronage and the...
# 1        Hey, thanks for the rating! This motivates us ...
# 2        Hey there, we're pleased that you enjoyed your...
# 3        Hi there, we are sorry for any hassle you have...
# 4        Hello, we would like to know more about it. Pl...
# ...                                                    ...
# 1358713  Dear Sania,\n\nWe got glued on your feedback.W...
# 1358714  Dear Durga,\n\nYour incessant delight is our r...
# 1358715  Dear Abishek,\n\nWe are always excited about o...
# 1358716  Kartik,\nExtremely sorry about the experience ...
# 1358717  Mayur,\nWe are very sorry for the experience y...
#
#                   repliedAt           Platform
# 0       2025-02-10 18:42:33  Google Play Store
# 1       2025-02-10 18:32:26  Google Play Store
# 2       2025-02-10 18:32:27  Google Play Store
# 3       2025-02-10 18:32:26  Google Play Store
# 4       2025-02-10 18:32:26  Google Play Store
# ...                     ...                ...
# 1358713 2015-03-28 13:06:02  Google Play Store
# 1358714 2015-03-28 10:36:11  Google Play Store
# 1358715 2015-03-27 17:25:20  Google Play Store
# 1358716 2015-03-26 15:17:10  Google Play Store
# 1358717 2015-03-24 10:09:05  Google Play Store
#
# [1340005 rows x 6 columns]

# %%
df_apple.isnull().sum()
# Out:
# date                   0
# review                 0
# rating                 0
# isEdited               0
# userName               0
# title                  0
# developerResponse    633
# Company                0
# Platform               0
# dtype: int64

# %%
df_apple.shape
# Out:
# (3240, 9)

# %%
df_apple.columns
# Out:
# Index(['date', 'review', 'rating', 'isEdited', 'userName', 'title',
#        'developerResponse', 'Company', 'Platform'],
#       dtype='object')

# %%
df2_apple = df_apple.drop(columns = ['isEdited', 'title', 'userName', 'Company'])
df3_apple = df2_apple.dropna()
df3_apple
# Out:
#                     date                                             review  \
# 1    2024-11-10 14:42:27  I have had multiple instances now of poor cust...
# 2    2024-11-10 20:06:17  I have placed the order in Swiggy with Box8 re...
# 4    2024-11-23 08:56:00  I have faced this issue multiple times but nev...
# 5    2023-02-24 13:29:45  I am absolutely furious with the terrible deli...
# 6    2021-08-15 09:24:27  I have ordered my breakfast at 12pm and the wa...
# ...                  ...                                                ...
# 3235 2024-10-08 02:09:50  Love the UX of the app. Of all the apps I have...
# 3236 2024-11-21 15:16:15  When I placed order, it showed 25 minutes to b...
# 3237 2024-11-11 06:00:59  I am a student, and Swiggy has fraud me, witho...
# 3238 2024-10-30 09:51:23  I have paid for food which included tip of x a...
# 3239 2024-10-01 07:48:44  worst customer service ever seen. \ni have ord...
#
#       rating                                  developerResponse   Platform
# 1          1  {'id': 48140594, 'body': 'We're disappointed t...  App Store
# 2          1  {'id': 48140595, 'body': 'Hello, we would like...  App Store
# 4          1  {'id': 48452648, 'body': 'Hey there, that shou...  App Store
# 5          1  {'id': 35100900, 'body': 'Hey Shakshi. We are ...  App Store
# 6          1  {'id': 24633540, 'body': 'Hi Maahi, we are sor...  App Store
# ...      ...                                                ...        ...
# 3235       5  {'id': 47321562, 'body': 'Hey there, we are th...  App Store
# 3236       1  {'id': 48430133, 'body': 'Hey there, that shou...  App Store
# 3237       1  {'id': 48166923, 'body': 'That doesn't seem ri...  App Store
# 3238       1  {'id': 47867386, 'body': 'Hi, we are sorry abo...  App Store
# 3239       1  {'id': 47166813, 'body': 'Hey there, that shou...  App Store
#
# [2607 rows x 5 columns]

# %%
df3_apple.reset_index()
# Out:
#       index                date  \
# 0         1 2024-11-10 14:42:27
# 1         2 2024-11-10 20:06:17
# 2         4 2024-11-23 08:56:00
# 3         5 2023-02-24 13:29:45
# 4         6 2021-08-15 09:24:27
# ...     ...                 ...
# 2602   3235 2024-10-08 02:09:50
# 2603   3236 2024-11-21 15:16:15
# 2604   3237 2024-11-11 06:00:59
# 2605   3238 2024-10-30 09:51:23
# 2606   3239 2024-10-01 07:48:44
#
#                                                  review  rating  \
# 0     I have had multiple instances now of poor cust...       1
# 1     I have placed the order in Swiggy with Box8 re...       1
# 2     I have faced this issue multiple times but nev...       1
# 3     I am absolutely furious with the terrible deli...       1
# 4     I have ordered my breakfast at 12pm and the wa...       1
# ...                                                 ...     ...
# 2602  Love the UX of the app. Of all the apps I have...       5
# 2603  When I placed order, it showed 25 minutes to b...       1
# 2604  I am a student, and Swiggy has fraud me, witho...       1
# 2605  I have paid for food which included tip of x a...       1
# 2606  worst customer service ever seen. \ni have ord...       1
#
#                                       developerResponse   Platform
# 0     {'id': 48140594, 'body': 'We're disappointed t...  App Store
# 1     {'id': 48140595, 'body': 'Hello, we would like...  App Store
# 2     {'id': 48452648, 'body': 'Hey there, that shou...  App Store
# 3     {'id': 35100900, 'body': 'Hey Shakshi. We are ...  App Store
# 4     {'id': 24633540, 'body': 'Hi Maahi, we are sor...  App Store
# ...                                                 ...        ...
# 2602  {'id': 47321562, 'body': 'Hey there, we are th...  App Store
# 2603  {'id': 48430133, 'body': 'Hey there, that shou...  App Store
# 2604  {'id': 48166923, 'body': 'That doesn't seem ri...  App Store
# 2605  {'id': 47867386, 'body': 'Hi, we are sorry abo...  App Store
# 2606  {'id': 47166813, 'body': 'Hey there, that shou...  App Store
#
# [2607 rows x 6 columns]

# %%
# ✅ Create a copy to avoid SettingWithCopyWarning
df4_apple = df3_apple.copy()

# ✅ Extract 'body' from 'developerResponse' safely
df4_apple["reply"] = df4_apple['developerResponse'].apply(lambda x: x.get("body") if isinstance(x, dict) else None)

# ✅ Drop the 'developerResponse' column correctly
df4_apple.drop(columns=["developerResponse"], inplace=True)

df4_apple.reset_index()
# Out:
#       index                date  \
# 0         1 2024-11-10 14:42:27
# 1         2 2024-11-10 20:06:17
# 2         4 2024-11-23 08:56:00
# 3         5 2023-02-24 13:29:45
# 4         6 2021-08-15 09:24:27
# ...     ...                 ...
# 2602   3235 2024-10-08 02:09:50
# 2603   3236 2024-11-21 15:16:15
# 2604   3237 2024-11-11 06:00:59
# 2605   3238 2024-10-30 09:51:23
# 2606   3239 2024-10-01 07:48:44
#
#                                                  review  rating   Platform  \
# 0     I have had multiple instances now of poor cust...       1  App Store
# 1     I have placed the order in Swiggy with Box8 re...       1  App Store
# 2     I have faced this issue multiple times but nev...       1  App Store
# 3     I am absolutely furious with the terrible deli...       1  App Store
# 4     I have ordered my breakfast at 12pm and the wa...       1  App Store
# ...                                                 ...     ...        ...
# 2602  Love the UX of the app. Of all the apps I have...       5  App Store
# 2603  When I placed order, it showed 25 minutes to b...       1  App Store
# 2604  I am a student, and Swiggy has fraud me, witho...       1  App Store
# 2605  I have paid for food which included tip of x a...       1  App Store
# 2606  worst customer service ever seen. \ni have ord...       1  App Store
#
#                                                   reply
# 0     We're disappointed to know the service has not...
# 1     Hello, we would like to know more about it. Pl...
# 2     Hey there, that should not have happened and w...
# 3     Hey Shakshi. We are really sad to know about t...
# 4     Hi Maahi, we are sorry to know about your expe...
# ...                                                 ...
# 2602  Hey there, we are thankful to you for your rev...
# 2603  Hey there, that should not have happened and w...
# 2604  That doesn't seem right. Kindly help us with m...
# 2605  Hi, we are sorry about the sub-par experience ...
# 2606  Hey there, that should not have happened and w...
#
# [2607 rows x 6 columns]

# %%
df4_apple.isnull().sum()
# Out:
# date        0
# review      0
# rating      0
# Platform    0
# reply       0
# dtype: int64

# %%
df3_playstore.isnull().sum()
# Out:
# content         0
# score           0
# at              0
# replyContent    0
# repliedAt       0
# Platform        0
# dtype: int64

# %%
df5_apple = df4_apple.drop(columns = ['reply', 'date'])
df5_apple.columns
# Out:
# Index(['review', 'rating', 'Platform'], dtype='object')

# %%
df5_apple.shape
# Out:
# (2607, 3)

# %%
df4_playstore = df3_playstore.drop(columns = ['replyContent', 'repliedAt', 'at'])
df5_playstore = df4_playstore.rename(columns = {'score' : 'rating', 'content' : 'review'})
df5_playstore.reset_index()
df5_playstore
# Out:
#                                                     review  rating  \
# 0                                                     good     5.0
# 1                                                     good     5.0
# 2                                        excellent service     5.0
# 3                                   food is very worstfood     1.0
# 4                                           warest service     1.0
# ...                                                    ...     ...
# 1358713  This is great! It was a little tough to keep p...     5.0
# 1358714                               They are super speed     5.0
# 1358715  Great app. Quick and  reliable services a clic...     5.0
# 1358716  Not able to register on app and order... Recei...     1.0
# 1358717  I ordered at 8PM. I had to get in touch with a...     1.0
#
#                   Platform
# 0        Google Play Store
# 1        Google Play Store
# 2        Google Play Store
# 3        Google Play Store
# 4        Google Play Store
# ...                    ...
# 1358713  Google Play Store
# 1358714  Google Play Store
# 1358715  Google Play Store
# 1358716  Google Play Store
# 1358717  Google Play Store
#
# [1340005 rows x 3 columns]

# %%
df5_playstore.shape
# Out:
# (1340005, 3)

# %%
merge_df = [df5_playstore, df5_apple]

# %%
combined_appstore_apple = pd.concat(merge_df, ignore_index=True)
combined_appstore_apple
# Out:
#                                                     review  rating  \
# 0                                                     good     5.0
# 1                                                     good     5.0
# 2                                        excellent service     5.0
# 3                                   food is very worstfood     1.0
# 4                                           warest service     1.0
# ...                                                    ...     ...
# 1342607  Love the UX of the app. Of all the apps I have...     5.0
# 1342608  When I placed order, it showed 25 minutes to b...     1.0
# 1342609  I am a student, and Swiggy has fraud me, witho...     1.0
# 1342610  I have paid for food which included tip of x a...     1.0
# 1342611  worst customer service ever seen. \ni have ord...     1.0
#
#                   Platform
# 0        Google Play Store
# 1        Google Play Store
# 2        Google Play Store
# 3        Google Play Store
# 4        Google Play Store
# ...                    ...
# 1342607          App Store
# 1342608          App Store
# 1342609          App Store
# 1342610          App Store
# 1342611          App Store
#
# [1342612 rows x 3 columns]

# %%
combined_appstore_apple['Platform'].unique()
# Out:
# array(['Google Play Store', 'App Store'], dtype=object)

# %%
combined_appstore_apple.isnull().sum()
# Out:
# review      0
# rating      0
# Platform    0
# dtype: int64

# %%
combined_appstore_apple_filtered = combined_appstore_apple[combined_appstore_apple["review"].apply(lambda x: len(x.split()) >= 20)]
combined_appstore_apple_filtered.reset_index()
# Out:
#           index                                             review  rating  \
# 0            11  Poor Delivery performance. No compensation for...     1.0
# 1            14  Had a very bad experience, I have made a order...     1.0
# 2            21  I have placed an order and right after 1 secon...     1.0
# 3            33  Don't make reservations for dine out.I had rec...     1.0
# 4            35  I had ordered a birthday cake from Swiggy. The...     1.0
# ...         ...                                                ...     ...
# 204396  1342607  Love the UX of the app. Of all the apps I have...     5.0
# 204397  1342608  When I placed order, it showed 25 minutes to b...     1.0
# 204398  1342609  I am a student, and Swiggy has fraud me, witho...     1.0
# 204399  1342610  I have paid for food which included tip of x a...     1.0
# 204400  1342611  worst customer service ever seen. \ni have ord...     1.0
#
#                  Platform
# 0       Google Play Store
# 1       Google Play Store
# 2       Google Play Store
# 3       Google Play Store
# 4       Google Play Store
# ...                   ...
# 204396          App Store
# 204397          App Store
# 204398          App Store
# 204399          App Store
# 204400          App Store
#
# [204401 rows x 4 columns]

# %%
combined_appstore_apple_filtered["review"].iloc[203109]
# Out:
# 'I have ordered in which all my gravy is spilled delivery guy even said that it is spilled , so when i informed swiggy then they provided me with coupon of Rs100. Next day when i opened my account my account is showing address you provided is not deliverable seriously ?? Just yesterday i had ordered from you guys. But story didnt end here in every address of my city my account is showing not deliverable. If you dont want me to give coupon aur compensate me its ok atleast dont block my account like that . Guys other app is way better than this because when i asked them about this situation they said they will contact me in email ?? What you think of me?'

# %%
combined_appstore_apple_filtered.to_csv(
    "swiggy_appstore_playstore.csv", 
    index=False, 
    escapechar="\\",  # Escapes problematic characters
    quoting=1  # Quotes fields containing special characters
)

# %%
combined_appstore_apple_filtered
# Out:
#                                                     review  rating  \
# 11       Poor Delivery performance. No compensation for...     1.0
# 14       Had a very bad experience, I have made a order...     1.0
# 21       I have placed an order and right after 1 secon...     1.0
# 33       Don't make reservations for dine out.I had rec...     1.0
# 35       I had ordered a birthday cake from Swiggy. The...     1.0
# ...                                                    ...     ...
# 1342607  Love the UX of the app. Of all the apps I have...     5.0
# 1342608  When I placed order, it showed 25 minutes to b...     1.0
# 1342609  I am a student, and Swiggy has fraud me, witho...     1.0
# 1342610  I have paid for food which included tip of x a...     1.0
# 1342611  worst customer service ever seen. \ni have ord...     1.0
#
#                   Platform
# 11       Google Play Store
# 14       Google Play Store
# 21       Google Play Store
# 33       Google Play Store
# 35       Google Play Store
# ...                    ...
# 1342607          App Store
# 1342608          App Store
# 1342609          App Store
# 1342610          App Store
# 1342611          App Store
#
# [204401 rows x 3 columns]
